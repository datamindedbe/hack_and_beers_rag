# %%
from src.chroma_db import VectorCollection, VectorDBItem, OpenAIEmbeddingModel, get_chromadb_client
chroma_client = get_chromadb_client("workitem_1")
TOKEN = ""
collection  = VectorCollection("test_collection", chroma_client, TOKEN, embedding_model=OpenAIEmbeddingModel.ADA_002)

# %%
collection.add_item("the cat ran through the grass very fast", None,"id_1")
collection.add_item("cave men hunted mammoths", None,"id_2")
collection.add_item("aliens have been spotted in the sky", None,"id_3")

# %%
collection.similar_items("the lion stalks its prey", n_results=5)
